# %%
Load data :
import pandas as pd

df = pd.read_csv("../data/raw/student_performance_raw.csv")
df.head()

Basic info:
df.info()
df.describe()

Missing Values Check:
df.isnull().sum()

Observations:
- Study_Hours contains missing values
- Attendance varies significantly across students
- Final marks show wide performance spread
